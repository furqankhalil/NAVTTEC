# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df1=pd.read_csv(r'E:\NAVTTEC\Dataset_files\csvfiles\Machine Learning\Unsupervised Learning datasets\air_passengers.csv')

# %%
df1.head()
# Out:
#   Year-Month  Passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121

# %%
#check the dtypes
df1.dtypes
# Out:
# Year-Month    object
# Passengers     int64
# dtype: object

# %%
#We are providing input to tell pandas  that we are trying to work with time series
df1=pd.read_csv(r'E:\NAVTTEC\Dataset_files\csvfiles\Machine Learning\Unsupervised Learning datasets\air_passengers.csv', parse_dates=['Year-Month'])

# %%
df1.dtypes
# Out:
# Year-Month    datetime64[ns]
# Passengers             int64
# dtype: object

# %%
df1.head()
# Out:
#   Year-Month  Passengers
# 0 1949-01-01         112
# 1 1949-02-01         118
# 2 1949-03-01         132
# 3 1949-04-01         129
# 4 1949-05-01         121

# %%
#it is recomended  we have to treat time as our index if we are working with time series
df1=pd.read_csv(r'E:\NAVTTEC\Dataset_files\csvfiles\Machine Learning\Unsupervised Learning datasets\air_passengers.csv', parse_dates=['Year-Month'],index_col='Year-Month')

# %%
df1.head()
# Out:
#             Passengers
# Year-Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
df1.tail()
# Out:
#             Passengers
# Year-Month
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432

# %%
#we can convenintly do slicing i.e obtain data for a specific time
df1['1951-04-01':'1952-03-01']
# Out:
#             Passengers
# Year-Month
# 1951-04-01         163
# 1951-05-01         172
# 1951-06-01         178
# 1951-07-01         199
# 1951-08-01         199
# 1951-09-01         184
# 1951-10-01         162
# 1951-11-01         146
# 1951-12-01         166
# 1952-01-01         171
# 1952-02-01         180
# 1952-03-01         193

# %%
#We can check values corresponding to specific time point
df1.loc['1960-05-01']
# Out:
# Passengers    472
# Name: 1960-05-01 00:00:00, dtype: int64

# %%
#plot tme series
df1.plot()
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8
df1.plot()
plt.show()

#plt.figure(figsize=(100,70))
#df1.plot()
#plt.show()

# %%
#Decompose the time series multiplicatively
df1_mul_decompose=seasonal_decompose(df1,model='multiplicative')
df1_mul_decompose.plot()
plt.show()

# %%
#we can convert multiplicative model into additive model
df1_log=df1.copy()
df1_log.head()
# Out:
#             Passengers
# Year-Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
df1_log['Passengers']=np.log(df1)

# %%
#visulazing the log transformed series
df1_log.plot()
plt.show()

# %%
#Compare with orignal series
plt.subplot(2,1,1)
plt.title("Orignal time Series")
plt.plot(df1)

plt.subplot(2,1,2)
plt.title("Transfomed time Series")
plt.plot(df1_log)

plt.tight_layout()
# Out:
# <ipython-input-23-919a11664724>:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,1,1)
# <ipython-input-23-919a11664724>:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(2,1,2)
