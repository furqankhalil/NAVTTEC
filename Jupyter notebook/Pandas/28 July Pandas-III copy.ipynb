# %%
import pandas as pd

# %%
pd.read_csv("/home/abbas/NAVTTEC/Dataset_files/csvfiles/Data.csv")
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
pd.read_csv("/home/abbas/NAVTTEC/Dataset_files/csvfiles/Data.csv",na_values=['no_value'])
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
pd.read_csv("/home/abbas/NAVTTEC/Dataset_files/csvfiles/Data.csv",na_values={'country':'no value'})
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
pd.read_csv("F:\csvfiles\Data.csv",keep_default_na=True)
# Out:
#      Country   Age   Salary Purchased
# 0  no_values  44.0  72000.0        No
# 1      Spain  27.0  48000.0       Yes
# 2    Germany  30.0  54000.0        No
# 3      Spain  38.0  61000.0        No
# 4    Germany  40.0      NaN       Yes
# 5     France  35.0  58000.0       Yes
# 6      Spain   NaN  52000.0        No
# 7     France  48.0  79000.0       Yes
# 8    Germany  50.0  83000.0        No
# 9     France  37.0  67000.0       Yes

# %%
pd.read_csv("F:\csvfiles\Data.csv",na_filter=True)
# Out:
#      Country   Age   Salary Purchased
# 0  no_values  44.0  72000.0        No
# 1      Spain  27.0  48000.0       Yes
# 2    Germany  30.0  54000.0        No
# 3      Spain  38.0  61000.0        No
# 4    Germany  40.0      NaN       Yes
# 5     France  35.0  58000.0       Yes
# 6      Spain   NaN  52000.0        No
# 7     France  48.0  79000.0       Yes
# 8    Germany  50.0  83000.0        No
# 9     France  37.0  67000.0       Yes

# %%
pd.read_csv("F:\csvfiles\Data.csv",na_filter=False)
# Out:
#      Country Age Salary Purchased
# 0  no_values  44  72000        No
# 1      Spain  27  48000       Yes
# 2    Germany  30  54000        No
# 3      Spain  38  61000        No
# 4    Germany  40              Yes
# 5     France  35  58000       Yes
# 6      Spain      52000        No
# 7     France  48  79000       Yes
# 8    Germany  50  83000        No
# 9     France  37  67000       Yes

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.isnull()
# Out:
#    Country    Age  Salary  Purchased
# 0    False  False   False      False
# 1    False  False   False      False
# 2    False  False   False      False
# 3    False  False   False      False
# 4    False  False    True      False
# 5    False  False   False      False
# 6    False   True   False      False
# 7    False  False   False      False
# 8    False  False   False      False
# 9    False  False   False      False

# %%
df=pd.read_csv("/home/abbas/NAVTTEC/Dataset_files/csvfiles/Data.csv")
df.isnull().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.isnull().sum().sum()
# Out:
# 2

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.notnull().sum()
# Out:
# Country      10
# Age           9
# Salary        9
# Purchased    10
# dtype: int64

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.notnull().sum().sum()
# Out:
# 38

# %%
df=pd.read_csv("/home/abbas/NAVTTEC/Dataset_files/csvfiles/Data.csv")
df.dropna(axis=1)
# Out:
#    Country Purchased
# 0   France        No
# 1    Spain       Yes
# 2  Germany        No
# 3    Spain        No
# 4  Germany       Yes
# 5   France       Yes
# 6    Spain        No
# 7   France       Yes
# 8  Germany        No
# 9   France       Yes

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.dropna(axis=0)
# Out:
#      Country   Age   Salary Purchased
# 0  no_values  44.0  72000.0        No
# 1      Spain  27.0  48000.0       Yes
# 2    Germany  30.0  54000.0        No
# 3      Spain  38.0  61000.0        No
# 5     France  35.0  58000.0       Yes
# 7     France  48.0  79000.0       Yes
# 8    Germany  50.0  83000.0        No
# 9     France  37.0  67000.0       Yes

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.dropna(how='any')
# Out:
#      Country   Age   Salary Purchased
# 0  no_values  44.0  72000.0        No
# 1      Spain  27.0  48000.0       Yes
# 2    Germany  30.0  54000.0        No
# 3      Spain  38.0  61000.0        No
# 5     France  35.0  58000.0       Yes
# 7     France  48.0  79000.0       Yes
# 8    Germany  50.0  83000.0        No
# 9     France  37.0  67000.0       Yes

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.dropna(how='all')
# Out:
#      Country   Age   Salary Purchased
# 0  no_values  44.0  72000.0        No
# 1      Spain  27.0  48000.0       Yes
# 2    Germany  30.0  54000.0        No
# 3      Spain  38.0  61000.0        No
# 4    Germany  40.0      NaN       Yes
# 5     France  35.0  58000.0       Yes
# 6      Spain   NaN  52000.0        No
# 7     France  48.0  79000.0       Yes
# 8    Germany  50.0  83000.0        No
# 9     France  37.0  67000.0       Yes

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.dropna(thresh=2)
# Out:
#       Country   Age   Salary Purchased
# 0   no_values  44.0  72000.0        No
# 1       Spain  27.0  48000.0       Yes
# 2     Germany  30.0  54000.0        No
# 3       Spain  38.0  61000.0        No
# 4     Germany  40.0      NaN       Yes
# 5      France  35.0  58000.0       Yes
# 6       Spain   NaN  52000.0        No
# 7      France  48.0  79000.0       Yes
# 8     Germany  50.0  83000.0        No
# 9      France  37.0  67000.0       Yes
# 11        pak   NaN      NaN        no

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.dropna(subset=['Age'])
# Out:
#       Country   Age   Salary Purchased
# 0   no_values  44.0  72000.0        No
# 1       Spain  27.0  48000.0       Yes
# 2     Germany  30.0  54000.0        No
# 3       Spain  38.0  61000.0        No
# 4     Germany  40.0      NaN       Yes
# 5      France  35.0  58000.0       Yes
# 7      France  48.0  79000.0       Yes
# 8     Germany  50.0  83000.0        No
# 9      France  37.0  67000.0       Yes
# 10        NaN   7.0      NaN       NaN

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.dropna(inplace=True)
print(df)
# Out:
#      Country   Age   Salary Purchased
# 0  no_values  44.0  72000.0        No
# 1      Spain  27.0  48000.0       Yes
# 2    Germany  30.0  54000.0        No
# 3      Spain  38.0  61000.0        No
# 5     France  35.0  58000.0       Yes
# 7     France  48.0  79000.0       Yes
# 8    Germany  50.0  83000.0        No
# 9     France  37.0  67000.0       Yes

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.dropna(inplace=False)
print(df)
# Out:
#       Country   Age   Salary Purchased
# 0   no_values  44.0  72000.0        No
# 1       Spain  27.0  48000.0       Yes
# 2     Germany  30.0  54000.0        No
# 3       Spain  38.0  61000.0        No
# 4     Germany  40.0      NaN       Yes
# 5      France  35.0  58000.0       Yes
# 6       Spain   NaN  52000.0        No
# 7      France  48.0  79000.0       Yes
# 8     Germany  50.0  83000.0        No
# 9      France  37.0  67000.0       Yes
# 10        NaN   7.0      NaN       NaN
# 11        pak   NaN      NaN        no

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.fillna(0)
# Out:
#       Country   Age   Salary Purchased
# 0   no_values  44.0  72000.0        No
# 1       Spain  27.0  48000.0       Yes
# 2     Germany  30.0  54000.0        No
# 3       Spain  38.0  61000.0        No
# 4     Germany  40.0      0.0       Yes
# 5      France  35.0  58000.0       Yes
# 6       Spain   0.0  52000.0        No
# 7      France  48.0  79000.0       Yes
# 8     Germany  50.0  83000.0        No
# 9      France  37.0  67000.0       Yes
# 10          0   7.0      0.0         0
# 11        pak   0.0      0.0        no

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.fillna({'Age':"68",
          'Salary':'111111'})
# Out:
#       Country Age  Salary Purchased
# 0   no_values  44   72000        No
# 1       Spain  27   48000       Yes
# 2     Germany  30   54000        No
# 3       Spain  38   61000        No
# 4     Germany  40  111111       Yes
# 5      France  35   58000       Yes
# 6       Spain  68   52000        No
# 7      France  48   79000       Yes
# 8     Germany  50   83000        No
# 9      France  37   67000       Yes
# 10        NaN   7  111111       NaN
# 11        pak  68  111111        no

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.fillna(method='ffill')
# Out:
#       Country   Age   Salary Purchased
# 0   no_values  44.0  72000.0        No
# 1       Spain  27.0  48000.0       Yes
# 2     Germany  30.0  54000.0        No
# 3       Spain  38.0  61000.0        No
# 4     Germany  40.0  61000.0       Yes
# 5      France  35.0  58000.0       Yes
# 6       Spain  35.0  52000.0        No
# 7      France  48.0  79000.0       Yes
# 8     Germany  50.0  83000.0        No
# 9      France  37.0  67000.0       Yes
# 10     France   7.0  67000.0       Yes
# 11        pak   7.0  67000.0        no

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.fillna(mehod='ffill',axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-8f3af722ae89> in <module>
#       1 df=pd.read_csv("F:\csvfiles\Data.csv")
# ----> 2 df.fillna(mehod='ffill',axis=0)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in fillna(self, value, method, axis, inplace, limit, downcast, **kwargs)
#    4032                      self).fillna(value=value, method=method, axis=axis,
#    4033                                   inplace=inplace, limit=limit,
# -> 4034                                   downcast=downcast, **kwargs)
#    4035
#    4036     @Appender(_shared_docs['replace'] % _shared_doc_kwargs)
#
# TypeError: fillna() got an unexpected keyword argument 'mehod'

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.fillna(0,limit=1)
# Out:
#       Country   Age   Salary Purchased
# 0   no_values  44.0  72000.0        No
# 1       Spain  27.0  48000.0       Yes
# 2     Germany  30.0  54000.0        No
# 3       Spain  38.0  61000.0        No
# 4     Germany  40.0      0.0       Yes
# 5      France  35.0  58000.0       Yes
# 6       Spain   0.0  52000.0        No
# 7      France  48.0  79000.0       Yes
# 8     Germany  50.0  83000.0        No
# 9      France  37.0  67000.0       Yes
# 10          0   7.0      NaN         0
# 11        pak   NaN      NaN        no

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.fillna(method='ffill',limit=2)
# Out:
#       Country   Age   Salary Purchased
# 0   no_values  44.0  72000.0        No
# 1       Spain  27.0  48000.0       Yes
# 2     Germany  30.0  54000.0        No
# 3       Spain  38.0  61000.0        No
# 4     Germany  40.0  61000.0       Yes
# 5      France  35.0  58000.0       Yes
# 6       Spain  35.0  52000.0        No
# 7      France  48.0  79000.0       Yes
# 8     Germany  50.0  83000.0        No
# 9      France  37.0  67000.0       Yes
# 10     France   7.0  67000.0       Yes
# 11        pak   7.0  67000.0        no

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.replace('Spain','Pak')
# Out:
#       Country   Age   Salary Purchased
# 0   no_values  44.0  72000.0        No
# 1         Pak  27.0  48000.0       Yes
# 2     Germany  30.0  54000.0        No
# 3         Pak  38.0  61000.0        No
# 4     Germany  40.0      NaN       Yes
# 5      France  35.0  58000.0       Yes
# 6         Pak   NaN  52000.0        No
# 7      France  48.0  79000.0       Yes
# 8     Germany  50.0  83000.0        No
# 9      France  37.0  67000.0       Yes
# 10        NaN   7.0      NaN       NaN
# 11        pak   NaN      NaN        no

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.replace({'Country':'France'},'none')
# Out:
#       Country   Age   Salary Purchased
# 0   no_values  44.0  72000.0        No
# 1       Spain  27.0  48000.0       Yes
# 2     Germany  30.0  54000.0        No
# 3       Spain  38.0  61000.0        No
# 4     Germany  40.0      NaN       Yes
# 5        none  35.0  58000.0       Yes
# 6       Spain   NaN  52000.0        No
# 7        none  48.0  79000.0       Yes
# 8     Germany  50.0  83000.0        No
# 9        none  37.0  67000.0       Yes
# 10        NaN   7.0      NaN       NaN
# 11        pak   NaN      NaN        no

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.replace('pak','ffill','none')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-88b6cd900879> in <module>
#       1 df=pd.read_csv("F:\csvfiles\Data.csv")
# ----> 2 df.replace('pak','ffill','none')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4040                                               value=value, inplace=inplace,
#    4041                                               limit=limit, regex=regex,
# -> 4042                                               method=method)
#    4043
#    4044     @Appender(_shared_docs['shift'] % _shared_doc_kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6440     def replace(self, to_replace=None, value=None, inplace=False, limit=None,
#    6441                 regex=False, method='pad'):
# ...

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.replace('Spain','pak',inplace=True)
print(df)
# Out:
#       Country   Age   Salary Purchased
# 0   no_values  44.0  72000.0        No
# 1         pak  27.0  48000.0       Yes
# 2     Germany  30.0  54000.0        No
# 3         pak  38.0  61000.0        No
# 4     Germany  40.0      NaN       Yes
# 5      France  35.0  58000.0       Yes
# 6         pak   NaN  52000.0        No
# 7      France  48.0  79000.0       Yes
# 8     Germany  50.0  83000.0        No
# 9      France  37.0  67000.0       Yes
# 10        NaN   7.0      NaN       NaN
# 11        pak   NaN      NaN        no

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.loc[0]
# Out:
# Country      no_values
# Age                 44
# Salary           72000
# Purchased           No
# Name: 0, dtype: object

# %%
df=pd.read_csv("/home/abbas/NAVTTEC/Dataset_files/csvfiles/Data.csv")
df.loc[[0,1,2]]
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No

# %%
df=pd.read_csv("/home/abbas/NAVTTEC/Dataset_files/csvfiles/Data.csv")
df.loc[[2,4]]
# Out:
#    Country   Age   Salary Purchased
# 2  Germany  30.0  54000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.loc[4,'Age']
# Out:
# 40.0

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.loc[0:5,'Age']
# Out:
# 0    44.0
# 1    27.0
# 2    30.0
# 3    38.0
# 4    40.0
# 5    35.0
# Name: Age, dtype: float64

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.loc[df['Age']<40]
# Out:
#     Country   Age   Salary Purchased
# 1     Spain  27.0  48000.0       Yes
# 2   Germany  30.0  54000.0        No
# 3     Spain  38.0  61000.0        No
# 5    France  35.0  58000.0       Yes
# 9    France  37.0  67000.0       Yes
# 10      NaN   7.0      NaN       NaN

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.iloc[2:4,0:4]
# Out:
#    Country   Age   Salary Purchased
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.iloc[0:4]
# Out:
#      Country   Age   Salary Purchased
# 0  no_values  44.0  72000.0        No
# 1      Spain  27.0  48000.0       Yes
# 2    Germany  30.0  54000.0        No
# 3      Spain  38.0  61000.0        No

# %%
df=pd.read_csv("F:\csvfiles\Data.csv")
df.iloc[[0,4]]
# Out:
#      Country   Age   Salary Purchased
# 0  no_values  44.0  72000.0        No
# 4    Germany  40.0      NaN       Yes
