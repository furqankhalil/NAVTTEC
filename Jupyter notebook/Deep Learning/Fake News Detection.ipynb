# %%
import numpy as np
import pandas as pd
df = pd.read_csv("E:\Study\AI(ML DL)\Tutorial\csvfiles\\news.csv")
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
X = df["text"].values
y = df["label"].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size =0.2, random_state=4)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vect = TfidfVectorizer(stop_words = 'english', max_df=0.7)
vect_train = vect.fit_transform(X_train)
vect_test = vect.transform(X_test)
# Out:
# <5068x60719 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1328376 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import PassiveAggressiveClassifier
pac = PassiveAggressiveClassifier(max_iter = 50)
pac.fit(vect_train,y_train)
y_pred = pac.predict(vect_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
print(round(accuracy_score(y_test,y_pred)*100,2),'%')
confusion_matrix(y_test,y_pred)
# Out:
# 93.29 %
# array([[567,  41],
#        [ 44, 615]], dtype=int64)

# %%
#returns a dictionary of terms as keys and values as feature indices
vect.vocabulary_
# Out:
# {'bamacare': 5981,
#  'supreme': 52636,
#  'court': 13266,
#  'case': 9750,
#  'gut': 24271,
#  'health': 25075,
#  'care': 9589,
#  'law': 31369,
#  'leave': 31516,
#  'millions': 34986,
#  'americans': 3654,
#  'facing': 20088,
#  'severe': 48619,
#  'consequences': 12459,
#  'king': 30417,
#  'burwell': 8984,
#  'lawsuit': 31391,
#  'originated': 38746,
#  'conservative': 12468,
#  'libertarian': 31890,
#  'think': 54172,
#  'tanks': 53345,
#  'alleges': 3379,
#  'stray': 51918,
#  'phrase': 40806,
#  'affordable': 2842,
#  'act': 2427,
#  'exchange': 19577,
#  'established': 19229,
#  'state': 51412,
#  'means': 34210,
#  'federal': 20559,
#  'government': 23587,
#  'isn': 28746,
#  'allowed': 3431,
#  'provide': 42907,
#  'subsidies': 52234,
#  'residents': 45577,
#  'states': 51425,
#  'refused': 44829,
#  'establish': 19228,
#  'insurance': 28078,
#  'exchanges': 19581,
#  '13': 240,
#  'district': 16613,
#  'columbia': 11735,
#  'bid': 7079,
#  'derail': 15377,
# ...

# %%
#returns the inverse document frequency vector of the document passed as a parameter
vect.idf_
# Out:
# array([5.61887583, 2.63117573, 8.83775166, ..., 8.83775166, 8.83775166,
#        8.83775166])

# %%
vect.get_feature_names()
# Out:
# ['00',
#  '000',
#  '000000031',
#  '00000031',
#  '000035',
#  '00006',
#  '0001pt',
#  '0002',
#  '000billion',
#  '000ft',
#  '000km',
#  '001',
#  '0011',
#  '002',
#  '003',
#  '004',
#  '005',
#  '005s',
#  '00684',
#  '006s',
#  '007s',
#  '008',
#  '008s',
#  '009',
#  '00am',
#  '00pm',
#  '01',
#  '010',
#  '011',
#  '012',
#  '013c2812c9',
#  '014',
#  '015',
#  '016',
#  '018',
#  '02',
#  '020',
#  '022',
#  '023',
#  '024',
#  '025',
#  '027',
#  '02714',
#  '028',
#  '02870',
#  '03',
#  '030',
#  '031',
#  '032',
#  '0325',
#  '033',
#  '037',
#  '03747',
#  '039',
#  '03eb',
#  '04',
#  '040',
#  '0400',
#  '042',
#  '044',
#  '047',
#  '048',
#  '049',
#  '04pm',
#  '05',
#  '050',
#  '052',
#  '053',
#  '056',
#  '058',
#  '06',
#  '0600',
#  '062',
#  '0640',
#  '066',
#  '068',
#  '06pm',
#  '07',
#  '0700',
#  '075',
#  '0750',
#  '076',
#  '07dryempjx',
#  '08',
#  '080',
#  '082',
#  '084',
#  '0843',
#  '085',
#  '0851',
#  '089',
#  '0891',
#  '09',
# ...
