# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('E:\\Study\\Python\\csvfiles\\tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.shape
# Out:
# (244, 7)

# %%
df.keys()
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df2 = df[['total_bill', 'tip','size']]
df2
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
X=df2.drop('total_bill',axis=1)
y=df2['total_bill']
print(X.shape,'\n',y.shape)
# Out:
# (244, 2)
#  (244,)

# %%
X_train,X_test,y_train,y_test=train_test_split (X,y,test_size=0.2,random_state=13)
#this will give use four data sets
print(X_train.shape,"\n",X_test.shape,"\n",y_train.shape,"\n",y_test.shape)
# Out:
# (195, 2)
#  (49, 2)
#  (195,)
#  (49,)

# %%
sc=StandardScaler()
sc.fit(X_train)
#StandardScaler will learn S.D and Mean from data
# Out:
# StandardScaler()

# %%
sc.mean_
# Out:
# array([2.99251282, 2.58461538])

# %%
sc.scale_
# Out:
# array([1.39166764, 0.9643753 ])

# %%
X_train.describe()
#it gives us the details of numerical features
# Out:
#               tip        size
# count  195.000000  195.000000
# mean     2.992513    2.584615
# std      1.395250    0.966858
# min      1.000000    1.000000
# 25%      2.000000    2.000000
# 50%      2.880000    2.000000
# 75%      3.575000    3.000000
# max     10.000000    6.000000

# %%
X_train_sc=sc.transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
print(X_train_sc,"\n\n",X_test_sc)
# Out:
# [[ -4.80371295  -5.5483929 ]
#  [ -4.95034218  -6.70454689]
#  [ -4.22785994  -6.70454689]
#  [ -4.60376398  -6.70454689]
#  [ -5.07830952  -9.01685487]
#  [ -4.27051572  -7.86070088]
#  [ -4.88102654  -9.01685487]
#  [ -5.17428502  -9.01685487]
#  [ -4.93701225  -9.01685487]
#  [ -4.92101634  -9.01685487]
#  [ -4.27051572  -5.5483929 ]
#  [ -4.67041364  -9.01685487]
#  [ -5.06764557  -9.01685487]
#  [ -5.07031156  -9.01685487]
#  [ -4.93701225  -9.01685487]
#  [ -5.14762516  -9.01685487]
#  [ -4.80371295  -9.01685487]
#  [ -4.80371295  -6.70454689]
#  [ -4.80371295  -9.01685487]
#  [ -4.55844222  -9.01685487]
#  [ -5.13696121  -9.01685487]
#  [ -4.09722662  -9.01685487]
#  [ -5.07031156  -7.86070088]
#  [ -4.45713475  -9.01685487]
#  [ -5.33691017  -9.01685487]
#  [ -4.27051572  -4.39223891]
#  [ -4.93701225  -9.01685487]
#  [ -4.53711433  -9.01685487]
#  [ -5.25159862  -9.01685487]
#  [ -4.74772724  -9.01685487]
#  [ -4.61442793  -7.86070088]
#  [ -5.12363128  -9.01685487]
# ...

# %%
X_train_sc=pd.DataFrame(X_train_sc,columns=['tip','size'])
X_test_sc=pd.DataFrame(X_train_sc,columns=['tip','size'])

# %%
print(X_train_sc)
X_test_sc
# Out:
#           tip       size
# 0   -4.803713  -5.548393
# 1   -4.950342  -6.704547
# 2   -4.227860  -6.704547
# 3   -4.603764  -6.704547
# 4   -5.078310  -9.016855
# ..        ...        ...
# 190 -5.070312  -6.704547
# 191 -5.158289  -7.860701
# 192 -5.016992  -9.016855
# 193 -5.070312  -9.016855
# 194 -5.115633 -10.173009
#
# [195 rows x 2 columns]
#           tip       size
# 0   -4.803713  -5.548393
# 1   -4.950342  -6.704547
# 2   -4.227860  -6.704547
# 3   -4.603764  -6.704547
# 4   -5.078310  -9.016855
# ..        ...        ...
# 190 -5.070312  -6.704547
# 191 -5.158289  -7.860701
# 192 -5.016992  -9.016855
# 193 -5.070312  -9.016855
# 194 -5.115633 -10.173009
#
# [195 rows x 2 columns]

# %%
X_train_sc.describe().round(3)
# Out:
#            tip     size
# count  195.000  195.000
# mean    -4.806   -8.341
# std      0.372    1.118
# min     -5.337  -10.173
# 25%     -5.070   -9.017
# 50%     -4.836   -9.017
# 75%     -4.650   -7.861
# max     -2.938   -4.392

# %% [markdown]
# # MinMaxScaler

# %%
df=pd.read_csv("E:\\Study\\Python\\DataCleaning\\houseprizes\\train.csv")

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...
