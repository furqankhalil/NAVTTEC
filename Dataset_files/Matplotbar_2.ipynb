# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Plotting on x-axis and y-axis
x=np.array([0,6])
y=np.array([0,250])

plt.plot(x,y)
plt.show()

# %%
# plotting using only marker(Only points without a line)

x=np.array([0,6])
y=np.array([0,250])

plt.plot(x,y,'o')
plt.show()

# %%
# Plotting on multiple values of x and y
xp=np.array([0,6,8,9,10])
yp=np.array([1,2,4,5,6])

plt.plot(xp,yp)
plt.show()

# %%
yp=np.array([1,2,4,5,6])

plt.plot(yp)
plt.show()

# %% [markdown]
# # Markers

# %%
# markers are used to specify the points
yp=np.array([1,2,4,5,6])
plt.plot(yp,marker='D')
plt.show()

# %%
# Format strings(fmt):marker|line|color
yp=np.array([1,2,4,5,6])
plt.plot(yp,'D-.g')
plt.show()

# %%
# marker size
yp=np.array([1,2,4,5,6])
plt.plot(yp,marker='o',ms=25)
plt.show()

# %%
# marker edge color
yp=np.array([1,2,4,5,6])
plt.plot(yp,marker='o',ms=25,mec='y')
plt.show()

# %%
# marker face color
yp=np.array([1,2,4,5,6])
plt.plot(yp,marker='o',ms=25,mec='red',mfc='m')
plt.show()

# %% [markdown]
# # Line

# %%
#Line style(linestyle or ls)
yp=np.array([1,2,4,5,6])
plt.plot(yp,ls='dashed')
plt.show()

# %%
# Line color(color or c)
yp=np.array([1,2,4,5,6])
plt.plot(yp,ls='-.',c='c')
plt.show()

# %%
#Line width (linewidth or lw)
yp=np.array([1,2,4,5,6])
plt.plot(yp, c='c', lw='10')
plt.show()

# %%
# Specifying a plot function for each line (Plotting multiple lines)( when x is default)

y1=np.array([3,8,1])
y2=np.array([6,2,7])

plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
# Drawing multiple line by specifying both x and y value

x1=np.array([4,5,7])
y1=np.array([3,8,1])
x2=np.array([9,5,3])
y2=np.array([6,2,7])

plt.plot(x1,y1,x2,y2)
plt.show()

# %% [markdown]
# # Labels

# %%
# Creating labels for x-axis and y-axis

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
# Creating Title for a plot

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
# Setting Font Properties for xlabel,ylabel and title

import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':25}
font2 = {'family':'serif','color':'green','size':20}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
# Positioning the title

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'cyan','size':25}
font2 = {'family':'serif','color':'black','size':20}

plt.title("Sports Watch Data", loc = 'right', fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Grid

# %%
# Adding grid lines to the graph

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'cyan','size':25}
font2 = {'family':'serif','color':'black','size':20}

plt.title("Sports Watch Data", loc = 'right', fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)

plt.grid()

plt.show()

# %%
# Adding Grid lines to an axis

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'cyan','size':25}
font2 = {'family':'serif','color':'black','size':20}

plt.title("Sports Watch Data", loc = 'right', fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %%
# Setting line properties for Grid

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'cyan','size':25}
font2 = {'family':'serif','color':'black','size':20}

plt.title("Sports Watch Data", loc = 'right', fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)

plt.grid(color = 'green' , ls = '--' , lw = 1.5)

plt.show()

# %% [markdown]
# # Subplots

# %%
# Drawing 2 subplots ..... subplot function(rows,columns,plot no.)

import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
# drawing 2 subplots of 2 rowa and 1 column

import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
# Drawing 6 plots (2 rows, 3 columns)

import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
# Giving title to each subplot

import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %%
# Super title: Gives title to th entire figure

import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# # Scatter Plots

# %%
#The scatter() function plots one dot for each observation.

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
# Drawing scatter plot for two observation

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
# You can set your own color for each scatter plot (Keyword color or c)

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, c = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, c = 'green')

plt.show()

# %%
# You can even set a specific color for each dot by using an array of colors as value for the c argument

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
# Colormap : A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 95, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()

plt.show()

# %%
# You can include the colormap in the drawing (Keyword colorbar)

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='spring_r')

plt.colorbar()

plt.show()

# %%
# You can change the size of the dots with the s argument.(Sizes array must be of same length as the x-axis and y-axis array)

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %%
# You can adjust the transparency of the dots with the alpha argument.

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.6)

plt.show()

# %%
# You can combine a colormap with different sizes on the dots. This is best visualized if the dots are transparent

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.6, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# # Bars

# %%
# Drawing bars 

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.bar(x, y)
plt.show()

# %%
# Drawing Horizontal Bars

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
# Bars colors (keyword: color=)

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "cyan")
plt.show()

# %%
# Bar Width (keyword width , default width is 0.8)

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.3 , color='green')
plt.show()

# %%
# Bar Height (Keyword: Height , default height is 0.8)

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.6)
plt.show()

# %% [markdown]
# # Histogram

# %%
# A histogram is a graph showing frequency distributions.
# Creating a histogram (keyword hist())

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# # Pie Charts

# %%
# Creating a pie chart (Keyword: pie())
# Pie Chart draws one piece called wedge for each value in the array
# By default the plotting of the first wedge starts from the x-axis and move counterclockwise

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
# Giving labels to each wedge (keyword: label)

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
# mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels =["Apples", "Bananas", "Cherries", "Dates"])
plt.show()

# %%
# Start Angle: you can change the start angle by specifying a startangle parameter.

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 160)
plt.legend()
plt.show()

# %%
# Explode: explode value is an array to specify how far to stand from the centre for each wedge

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0, 0.2, 0, 0.4]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
# Adding Shadow to the pie chart (keyword: shadow=True)

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0.3, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
# Color for each wedge (keyword color='')

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["r", "y", "m", '#5C3317']

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
# Legend: To add a list of explanation for each wedge, use the legend() function

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
# Legend With Header: To add a header to the legend, add the title parameter to the legend function.

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Fruits:")
plt.show()

# %% [markdown]
#   # THE END
